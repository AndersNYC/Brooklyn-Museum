# %%
import operator,collections,heapq

# %%
import csv

# %%
import pandas

# %%
import json

# %%
import nltk

# %%
from nameparser import HumanName

# %%
def get_human_names(text):
    tokens = nltk.tokenize.word_tokenize(text)
    pos = nltk.pos_tag(tokens)
    sentt = nltk.ne_chunk(pos, binary = False)
    person_list = []
    person = []
    name = ""
    for subtree in sentt.subtrees(filter=lambda t: t.label() == 'PERSON'):
        for leaf in subtree.leaves():
            person.append(leaf[0])
        if len(person) > 1: #avoid grabbing lone surnames
            for part in person:
                name += part + ' '
            if name[:-1] not in person_list:
                person_list.append(name[:-1])
            name = ''
        person = []

    return (person_list)

text = pandas.read_csv("Users_one_fourth_NLTK-TEST.csv")

# %%
names = get_human_names(text)
print("LAST, FIRST")
for name in names: 
    last_first = HumanName(name).last + ', ' + HumanName(name).first
    print(last_first)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-dd421425003a> in <module>()
# ----> 1 names = get_human_names(text)
#       2 print("LAST, FIRST")
#       3 for name in names:
#       4     last_first = HumanName(name).last + ', ' + HumanName(name).first
#       5     print(last_first)
#
# <ipython-input-49-f8cb0eadb7c7> in get_human_names(text)
#       1 def get_human_names(text):
# ----> 2     tokens = nltk.tokenize.word_tokenize(text)
#       3     pos = nltk.pos_tag(tokens)
#       4     sentt = nltk.ne_chunk(pos, binary = False)
#       5     person_list = []
#
# /Users/anderswallace/anaconda/lib/python3.5/site-packages/nltk/tokenize/__init__.py in word_tokenize(text, language)
#     102     :param language: the model name in the Punkt corpus
#     103     """
# --> 104     return [token for sent in sent_tokenize(text, language)
# ...

# %%
def get_human_names(text):
    tokens = nltk.tokenize.word_tokenize(text)
    pos = nltk.pos_tag(tokens)
    sentt = nltk.ne_chunk(pos)
    person_list = []
    person = []
    name = ""
    for subtree in sentt.subtrees(filter=lambda t: t.label() == 'PERSON'):
        for leaf in subtree.leaves():
            person.append(leaf[0])
        if len(person) > 1: #avoid grabbing lone surnames
            for part in person:
                name += part + ' '
            if name[:-1] not in person_list:
                person_list.append(name[:-1])
            name = ''
        person = []

    return (person_list)

with open('Users_one_fourth_NLTK-TEST.csv', 'r') as file:
    text = file.read()

names = get_human_names(text)
print("LAST, FIRST")
for name in names: 
   last_first = HumanName(name).last + ', ' + HumanName(name).first
   print(last_first)
# Out:
# LAST, FIRST
# Guy, Francis
# Scene, Winter
# Brooklyn, Downtown
# Sargent, John
# Ringold, Faith
# Lakes, Great
# Hartman, Bertram
# Dance, Buffalo
# Bridge, Brooklyn
# Koch, John
# Bourgeois, Louise
# Gilbert, Aaron
# Cadmus, Paul
# Rosalie, Mt
# Biederman, Charles
# Charles, John
# Lichtenstein, Roy
# Weir, Alden
# Sunshine, Wind
# Donne, John
# Flannagan, John
# Koch, J
# Heaton, Were
# Hassam, Did
# Glackens, William
# Wiley, Khinde
# Bellows, George
# Thompson, Bob
# Wiley, Kehinde
# Caritas, Amor
# Domain, Public
# Albers, Josef
# Tenor,
# College, Black
# Jones, Lois
# Hawkins, William
# Bleckner, Ross
# Pereira, Irene
# Hoffman, Hans
# Rothko, Mark
# Tufts, James
# Chino, Did
# OKeeffe, Georgia
# Katie, Hello
# Stephanie, Hello
# Trunks, Dark
# Emmet, Lydia
# Merritt, William
# Dresser, Christopher
# Russel, Joseph
# Niente, Dolce
# Buddhist, Mariachi
# Powers, Hiram
# Jessica, Hi
# Bryant, William
# Wei, Ai
# Kahlo, Frida
# Magdalene, Mary
# Katie, Hi
# Buraq, Al
# ...

# %%
def get_human_names(text):
    tokens = nltk.tokenize.word_tokenize(text)
    pos = nltk.pos_tag(tokens)
    sentt = nltk.ne_chunk(pos)
    person_list = []
    person = []
    name = ""
    for subtree in sentt.subtrees(filter=lambda t: t.label() == 'PERSON'):
        for leaf in subtree.leaves():
            person.append(leaf[0])
        if len(person) > 1: #avoid grabbing lone surnames
            for part in person:
                name += part + ' '
            if name[:-1] not in person_list:
                person_list.append(name[:-1])
            name = ''
        person = []

    return (person_list)

with open('Users_two_fourths_NLTK-TEST.csv', 'r') as file:
    text = file.read()

names = get_human_names(text)
print("LAST, FIRST")
for name in names: 
   last_first = HumanName(name).last + ', ' + HumanName(name).first
   print(last_first)
# Out:
# LAST, FIRST
# Qs, Quick
# Marchais, Jacques
# Marilyn, So
# Mintor, Is
# Girls, Brown
# Dickinson, Emily
# Pappo, Dan
# O'Keeffe, Georgia
# Republics, Banana
# O'Keefe, Georgia
# News, Fake
# Delaunay, Sonia
# Georgia, Did
# Mount, William
# Kardashian, Kim
# Hutchinson, Anne
# Mayer, Ruth
# Buchanan, Beverly
# Ammon, Zeus
# Alison, Thanks
# Farrow, Jeanette
# Gough, Van
# MM, Does
# GO, Did
# Kahlo, Frieda
# Ranch, Ghost
# Chicago, Judy
# Katie, Thanks
# Blum, Robert
# Lachaise, Gaston
# Loren, Sophia
# O, Georgia
# Okeefe, Georgia
# Roadshow, Antiques
# Stieglitz, Alfred
# Tompkins, Betty
# Longo, Robert
# Longo, Did
# Pollock, Jackson
# Blackwell, Elizabeth
# Herschel, Caroline
# Allison, Thanks
# Tissot, John
# Where, Hello
# Torres, Felix
# Elizabeth, Thanks
# Arthur, Any
# Carr, Emily
# Kahlo, Frida
# Bartoli, Jose
# Mpane, Aime
# Woolf, Virginia
# Musem, Brooklyn
# Owens, Rick
# Davis, Anthony
# Bridge, Dam
# Liepke, Malcolm
# Mignot, Remy
# Roman, Ancient
# Allison, Hey
# ...

# %%
def get_human_names(text):
    tokens = nltk.tokenize.word_tokenize(text)
    pos = nltk.pos_tag(tokens)
    sentt = nltk.ne_chunk(pos)
    person_list = []
    person = []
    name = ""
    for subtree in sentt.subtrees(filter=lambda t: t.label() == 'PERSON'):
        for leaf in subtree.leaves():
            person.append(leaf[0])
        if len(person) > 1: #avoid grabbing lone surnames
            for part in person:
                name += part + ' '
            if name[:-1] not in person_list:
                person_list.append(name[:-1])
            name = ''
        person = []

    return (person_list)

with open('Users_three_fourths_NLTK-TEST.csv', 'r') as file:
    text = file.read()

names = get_human_names(text)
print("LAST, FIRST")
for name in names: 
   last_first = HumanName(name).last + ', ' + HumanName(name).first
   print(last_first)
# Out:
# LAST, FIRST
# John, Elton
# Jones, David
# Robert, David
# Christmas, Merry
# Lawrence,
# Umbrella, Blue
# Israeli, Any
# Bowie, David
# Trivia, Bowie
# Jones, Davey
# Jones, David
# Underwood, George
# Jagger, Mick
# Jean, Blue
# Low, Heroes
# Eno, Brian
# Visconti, Tony
# Nomi, Klaus
# Starman, Steven
# Vandross, Luther
# Stardust, Ziggy
# Pepper,
# Thomas, Michalene
# Lennon, John
# Bowman, Dave
# Bugaloo, Electric
# Johnson, David
# Baxter, David
# David, David
# Oddity, Space
# Chicago, Judy
# Beginners, Absolute
# Factory, Kids
# Tyler, Steven
# Lennox, Annie
# Dance, Just
# Tom, Major
# Jones, Grace
# Faithfull, Marianne
# Jones, Davy
# Mr., Christmas
# Jones, Duncan
# People, Earth
# Mercury, Freddy
# Crosby, Bing
# Roberts, David
# Jones, Duncan
# Mercury, Freddie
# Jones, Dave
# Heroes, Lodger
# Warhol, Andy
# Russell, Bertrand
# Kafka, Franz
# Brown, David
# Landing, Moon
# Dory, Hunky
# Wars, Star
# Potter, Harry
# Jager, Mick
# Monroe, Ummm
# Monroe, Jonathan
# ...

# %%
def get_human_names(text):
    tokens = nltk.tokenize.word_tokenize(text)
    pos = nltk.pos_tag(tokens)
    sentt = nltk.ne_chunk(pos)
    person_list = []
    person = []
    name = ""
    for subtree in sentt.subtrees(filter=lambda t: t.label() == 'PERSON'):
        for leaf in subtree.leaves():
            person.append(leaf[0])
        if len(person) > 1: #avoid grabbing lone surnames
            for part in person:
                name += part + ' '
            if name[:-1] not in person_list:
                person_list.append(name[:-1])
            name = ''
        person = []

    return (person_list)

with open('Users_four_fourths_NLTK-TEST.csv', 'r') as file:
    text = file.read()

names = get_human_names(text)
print("LAST, FIRST")
for name in names: 
   last_first = HumanName(name).last + ', ' + HumanName(name).first
   print(last_first)
# Out:
# LAST, FIRST
# Nomi, Klaus
# Jones, David
# Jones, David
# Jagger, Mick
# John, Elton
# Love, Modern
# Jean, Blue
# Eno, Brian
# Road, Abbey
# Mercury, Freddie
# Bowie, David
# Check, Spell
# Beginners, Absolute
# Fell, Man
# Lennon, John
# Vandross, Luther
# Jones, Duncan
# Visconti, Tony
# Lonley, Pepper
# Nono, Klaus
# Vandross, C
# Peppers,
# Park, Battery
# Trivia, Bowie
# Underwood, George
# Pepper, Labyrinth
# Pop, Iggy
# Christmas, Merry
# Fell, Who
# Jaggar, Mick
# Burns, Terry
# Sise, Lower
# Chicago, Judy
# Pimentels, Wanda
# Peaks, Twin
# Dory, Hunky
# Heroes, Low
# Visconti, Toni
# Bowiestein, Dave
# Segal, George
# Eggelsworth, David
# Exhibit, David
# Sherman, David
# Crystal, Dark
# Turner, Tina
# Wynne, Rob
# Hathor, Goddess
# Turner, Tonight
# Stardust, Ziggy
# Jagger, Mic
# Peale, Charles
# Faithful, Marianne
# Egyptian, Which
# Levine, David
# Jacquette, Yvonne
# Jones, Davey
# Crosby, Bing
# Village, East
# Dancing, Mick
# Walk, Fire
# Rubin, Rick
# Rowd, Abbey
# ...

# %%
def get_human_names(text):
    tokens = nltk.tokenize.word_tokenize(text)
    pos = nltk.pos_tag(tokens)
    sentt = nltk.ne_chunk(pos)
    person_list = []
    person = []
    name = ""
    for subtree in sentt.subtrees(filter=lambda t: t.label() == 'PERSON'):
        for leaf in subtree.leaves():
            person.append(leaf[0])
        if len(person) > 1: #avoid grabbing lone surnames
            for part in person:
                name += part + ' '
            if name[:-1] not in person_list:
                person_list.append(name[:-1])
            name = ''
        person = []

    return (person_list)

with open('just_messages.csv', 'r') as file:
    text = file.read()

names = get_human_names(text)
print("LAST, FIRST")
for name in names: 
   last_first = HumanName(name).last + ', ' + HumanName(name).first
   print(last_first)
# Out:
# LAST, FIRST
# Guy, Francis
# Scene, Winter
# Brooklyn, Downtown
# Sargent, John
# Hoffman, Hans
# Ringold, Faith
# Lakes, Great
# Hartman, Bertram
# Artists, Graphic
# Clock, Albatross
# Dance, Buffalo
# Bridge, Brooklyn
# Koch, John
# Bourgeois, Louise
# Gilbert, Aaron
# Hale, Nathan
# Cadmus, Paul
# Rosalie, Mt
# Biederman, Charles
# Charles, John
# Lichtenstein, Roy
# Weir, Alden
# Sunshine, Wind
# Donne, John
# Paul,
# Flannagan, John
# Eakins, Thomas
# Koch, J
# Stem, Carved
# Heaton, Were
# Hassam, Did
# Glackens, William
# WIlson, Charles
# Wiley, Khinde
# Bellows, George
# Station, Penn
# Thompson, Bob
# Wiley, Kehinde
# Caritas, Amor
# Domain, Public
# Albers, Josef
# Tenor,
# College, Black
# Jones, Lois
# Hawkins, William
# Bleckner, Ross
# Pereira, Irene
# Hofmann, Hans
# Rothko, Mark
# Ray, Man
# Tufts, James
# Storage, Luce
# Dewing, Thomas
# Egypt, Ancient
# Chino, Did
# Chino, Grace
# OKeeffe, Georgia
# Katie, Hello
# Stephanie, Hello
# Trunks, Dark
# Emmet, Lydia
# ...
